# %%
# Hyades - October 2018
# Hyades1 = data with radial velocity
# Hyades2 = data with radial 
dr2_wrv = 'SELECT TOP 10000 gaia.source_id, gaia.ra, gaia.ra_error, gaia.dec,gaia.dec_error, \
gaia.pmra, gaia.pmra_error, gaia.pmdec, gaia.pmdec_error, gaia.radial_velocity, \
gaia.radial_velocity_error, gaia.parallax, gaia.parallax_error, gaia.phot_g_mean_mag, \
gaia.phot_bp_mean_mag, gaia.phot_rp_mean_mag FROM gaiadr2.gaia_source as gaia WHERE gaia.ra >= 35 \
and gaia.ra <= 95 and gaia.dec <= 40 and gaia.dec >= -5 and gaia.parallax > 19.5 and \
gaia.parallax < 23.5 and gaia.pmra is not null and gaia.pmdec is not null and \
gaia.phot_bp_mean_mag is not null and gaia.phot_rp_mean_mag is not null and \
gaia.phot_g_mean_mag is not null and gaia.radial_velocity is not null'

import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
import statistics as stat
import scipy.stats as st
import random as rand

def pc_ly(x):
    return (1/(float(x)/1000))*3.26156
def mas_deg(x):
    return x*(1/1000)/3600
def abs_mag(x,y):
    return x - (5 * (np.log10(y/10))) 
def color(x,y):
    return [y[i]-x[i] for i in range(len(x))]
def z_score(x,y,z):
    return (x-y)/z
    
hyades1 = pd.read_csv('/Users/landonbuechner/Documents/Git Hub Repositories/Hyades-Open-Cluster/dr2_wrv.csv')

print('-- Hyades open cluster (Epoch J2015.5) -- ')
print()
print('-5 <= dec <= 40\n35 <= ra <= 95\n19 <= parallax <= 24')

ra0, dec0 = hyades1['ra'], hyades1['dec'] 
pmra, pmdec = mas_deg(hyades1['pmra']), mas_deg(hyades1['pmdec'])
plt.figure(figsize=(8,8))
plt.style.use('seaborn')
plt.xlim([95,35])
plt.ylim([-7,37])
plt.xlabel('ra')
plt.ylabel('dec')
plt.title('Initial Data - {} stars'.format(len(hyades1)))
for i in range(len(hyades1)):
    ra = []
    dec = []
    for x in range(1,5000,10):
        ra.append(ra0[i]+(pmra[i]*x*10))
        dec.append(dec0[i]+(pmdec[i]*x*10))
    plt.scatter(ra, dec, s = .2, c = 'k'  )
plt.show()
hyades1.head()
# Out:
# -- Hyades open cluster (Epoch J2015.5) --
#
# -5 <= dec <= 40
# 35 <= ra <= 95
# 19 <= parallax <= 24
#              source_id         ra  ra_error        dec  dec_error        pmra  \
# 0    18161561269840768  39.965219  0.037198   5.580438   0.031024  246.469926
# 1   152451414656258560  65.979650  0.051405  27.822370   0.028324  -16.019586
# 2   223787797787973120  57.004644  0.035408  38.344293   0.020976  -64.729618
# 3   161788841059992960  73.734379  0.107306  34.168481   0.077216  -57.467374
# 4  3373723237944913280  92.424369  0.040811  19.092142   0.040188  -31.676959
#
#    pmra_error       pmdec  pmdec_error  radial_velocity  \
# 0    0.079845 -107.183118     0.066133        -1.834031
# 1    0.114759  -40.951804     0.077585        38.228804
# 2    0.094762   12.172372     0.063737       -28.901162
# 3    0.202092  -63.925680     0.125674       -15.769661
# 4    0.078565 -170.374820     0.066466       -34.362040
#
# ...

# %%
from sklearn.mixture import GaussianMixture

plt.scatter(hyades1['pmra'],hyades1['pmdec'],s=1)
plt.show()

X = pd.DataFrame(columns = ['pmra','pmdec'])
X['pmra'] = hyades1['pmra'] 
X['pmdec'] = hyades1['pmdec']

gmm = GaussianMixture(n_components=2).fit(X)

hyades1['proba'] = list([lis[1] for lis in gmm.predict_proba(X)])
high = hyades1[hyades1['proba'] > .5]

plt.scatter(high['pmra'],high['pmdec'],s=5, edgecolors = 'k', facecolors='none', alpha=.8)
plt.xlabel('pmra')
plt.ylabel('pmdec')
plt.title('Max: {} Min: {}'.format(max(high['proba']),min(high['proba'])))
plt.show()

plt.scatter(high['ra'],high['dec'],s=5, edgecolors = 'k', facecolors='none', alpha=.8)
plt.xlabel('pmra')
plt.ylabel('pmdec')
plt.title('Stars: {}'.format(len(high)))
plt.show()

# %%
from sklearn.mixture import GaussianMixture

f, (ax1, ax2) = plt.subplots(1, 2, sharey=False, figsize = (16,5))
ax1.hist(hyades1['pmra'],bins=100, color = 'k')
ax1.set_ylabel('-')
ax1.set_xticks([])
ax2
plt.show() 

X = pd.DataFrame(columns = ['pmra','pmdec'])
X['pmra'] = hyades1['pmra'] 
X['pmdec'] = hyades1['pmdec']

gmm = GaussianMixture(n_components=2).fit(X)
labels = gmm.predict(X)

f, (ax1, ax2) = plt.subplots(1, 2, sharey=False, figsize = (16,5))
ax1.scatter(X['pmra'], X['pmdec'], s=20, c=labels, cmap='spring', edgecolors = 'k', facecolors='none', alpha=.01)
ax1.set_xlabel('pmra')
ax1.set_ylabel('pmdec')
ax2.hist(hyades1['pmdec'],bins=100, color = 'k',orientation="horizontal")
ax2.set_yticks([])
plt.show()

# %%
hyades1['mix_lab'] = list(labels)

HYA = []
core_worv_gal = []
for i in range(len(hyades1)):
    if hyades1['mix_lab'][i] == 1:
        HYA.append(list(hyades1.loc[i]))
        
HYA = pd.DataFrame(HYA,columns = list(hyades1))

plt.figure(figsize=(14,9))
plt.scatter(hyades1['ra'],hyades1['dec'], s=25, edgecolors = 'k', facecolors='none')
plt.scatter(HYA['ra'],HYA['dec'], s=25, edgecolors = 'r', facecolors='none')
plt.xlabel('ra')
plt.ylabel('dec')
plt.show()

# %%
# membership 
members = []
delta = pmdec
mu = np.mean(pmdec)
std = np.std(pmdec)
score1 = [z_score(i,mu,std) for i in delta]
delta = pmra
mu = np.mean(pmra)
std = np.std(pmra)
score2 = [z_score(i,mu,std) for i in delta]
delta = hyades1['radial_velocity']
mu = np.mean(hyades1['radial_velocity'])
std = np.std(hyades1['radial_velocity'])
score3 = [z_score(i,mu,std) for i in delta]

for i in range(0,len(delta)):
    if score1[i] >=   -1.65 and score1[i] <=  1.65 \
        and score2[i] >=  -1.65 and score2[i] <=  1.65 \
        and score3[i] >=  -1.65 and score3[i] <=  1.65:
            members.append(list(hyades1.loc[i]))
        
# plotting filtered members 
members = pd.DataFrame(members, columns = list(hyades1))
ra0, dec0 = members['ra'], members['dec'] 
pmra, pmdec = mas_deg(members['pmra']), mas_deg(members['pmdec'])
plt.figure(figsize=(8,8))
plt.style.use('seaborn')
plt.xlim([95,35])
plt.ylim([-7,37])
plt.ylabel('dec (deg)')
plt.xlabel('ra (deg)')
plt.title('Phase 1 - {} stars'.format(len(members)))
for i in range(len(members)):
    ra = []
    dec = []
    for x in range(1,5000,50):
        ra.append(ra0[i]+(pmra[i]*x*10))
        dec.append(dec0[i]+(pmdec[i]*x*10))
    plt.scatter(ra, dec, s = .2, c = 'k'  )
plt.show()

# %%
# view of intermediate filtering over long term
plt.figure(figsize=(8,8))
plt.xlim([120,35])
plt.ylim([-7,37])
plt.ylabel('dec (deg)')
plt.xlabel('ra (deg)')
plt.title('Phase 1 - {} stars'.format(len(members)))
for i in range(len(members)):
    ra = []
    dec = []
    for x in range(1,5000,10):
        ra.append(ra0[i]+(pmra[i]*x*1000))
        dec.append(dec0[i]+(pmdec[i]*x*1000))
    plt.scatter(ra, dec, s = .2, c = 'k'  )
plt.show()

# point convergence
final = []
raa = []
decc = []
for i in range(len(members)):
    ra = []
    dec = []
    for x in range(1,5000,10):
        ra.append(ra0[i]+(pmra[i]*x*1000))
        dec.append(dec0[i]+(pmdec[i]*x*1000))
    raa.append(ra)
    decc.append(dec)

# D = [99,96] x [9,6]
for i in range(len(raa)):
    for x in range(len(raa[i])):
        if raa[i][x] <= 99 and raa[i][x] >= 96 and \
        decc[i][x] <= 10 and decc[i][x] >= 6:
            final.append(list(members.loc[i]))
            break

final = pd.DataFrame(final, columns = list(hyades1))

# plotting results 
plt.figure(figsize=(8,8))
plt.xlim([120,35])
plt.ylim([-7,37])
plt.ylabel('dec (deg)')
plt.xlabel('ra (deg)')
plt.title('Observed members (Hyades1) - {} stars'.format(len(final)))

ra0, dec0 = final['ra'], final['dec'] 
pmra, pmdec = mas_deg(final['pmra']), mas_deg(final['pmdec'])
for i in range(len(final)):
    ra = []
    dec = []
    for x in range(1,5000,10):
        ra.append(ra0[i]+(pmra[i]*x*1000))
        dec.append(dec0[i]+(pmdec[i]*x*1000))
    plt.scatter(ra, dec, s = .2, c = 'k'  )
plt.show()
print('Predicted point of convergence D = [99,96] x [10,6]')
print('Perryman et al., 1998, (96.6 ra, 5.8 dec) ')
# Out:
# Predicted point of convergence D = [99,96] x [10,6]
# Perryman et al., 1998, (96.6 ra, 5.8 dec)

# %%
from sklearn.mixture import GaussianMixture

X = pd.DataFrame(columns = ['pmra','pmdec'])
X['pmra'] = hyades1['pmra'] 
X['pmdec'] = hyades1['pmdec']

gmm = GaussianMixture(n_components=2).fit(X)
labels = gmm.predict(X)

plt.scatter(hyades1['pmra'],hyades1['pmdec'],s=5,c='k')
plt.scatter(final['pmra'],final['pmdec'],s=5,c='r')
plt.scatter(X['pmra'],X['pmdec'])
plt.show()

# %%
#color magnitude diagrams for different stages of membership
M_g = [abs_mag(hyades1['phot_g_mean_mag'][i],hyades1['parallax'][i]) for i in range(len(hyades1['ra']))]
M_rp = [abs_mag(hyades1['phot_rp_mean_mag'][i],hyades1['parallax'][i]) for i in range(len(hyades1['ra']))]
M_b = [abs_mag(hyades1['phot_bp_mean_mag'][i],hyades1['parallax'][i]) for i in range(len(hyades1['ra']))]
color_index = color(M_rp,M_b)
plt.figure(figsize=(7,7))
plt.title('Color-Magnitude - Initial Data')
plt.xlabel('(Bp-Rp)')
plt.ylabel('Absolute Magnitude ')
plt.xlim([0,3])
plt.ylim([13,2])
plt.scatter(color_index, M_g,marker='o', s=25,alpha = .5, c = 'k')
plt.style.use('seaborn')
plt.show() 

M_g = [abs_mag(members['phot_g_mean_mag'][i],members['parallax'][i]) for i in range(len(members['ra']))]
M_rp = [abs_mag(members['phot_rp_mean_mag'][i],members['parallax'][i]) for i in range(len(members['ra']))]
M_b = [abs_mag(members['phot_bp_mean_mag'][i],members['parallax'][i]) for i in range(len(members['ra']))]
color_index = color(M_rp,M_b)
plt.figure(figsize=(7,7))
plt.title('Color-Magnitude - Phase 1')
plt.xlabel('(Bp-Rp)')
plt.ylabel('Absolute Magnitude ')
plt.xlim([0,3])
plt.ylim([13,2])
plt.scatter(color_index, M_g,marker='o', s=25, alpha = .5,c = 'k')
plt.style.use('seaborn')
plt.show()

M_gF = [abs_mag(final['phot_g_mean_mag'][i],final['parallax'][i]) for i in range(len(final['ra']))]
M_rp = [abs_mag(final['phot_rp_mean_mag'][i],final['parallax'][i]) for i in range(len(final['ra']))]
M_b = [abs_mag(final['phot_bp_mean_mag'][i],final['parallax'][i]) for i in range(len(final['ra']))]
color_indexF = color(M_rp,M_b)
plt.figure(figsize=(7,7))
plt.title('Color-Magnitude - Finalized Selection (Hyades1): {} stars'.format(len(final)))
plt.xlabel('(Bp-Rp)')
plt.ylabel('Absolute Magnitude ')
plt.xlim([0,3])
plt.ylim([13,2])
plt.scatter(color_indexF, M_gF,marker='o', s=25, alpha = .5,c = 'k')
plt.style.use('seaborn')
plt.show()

# %%
# positions after 1,000,000 years
final['dist'] = [1/(i/1000) for i in final['parallax']] # pc 
final['rad_v'] = [i*(1.022035e-6) for i in final['radial_velocity']] # km/s -> pc / yr 
finra = []
findec = []
findist = []
pm_scalar = []

# final positions
for i in range(len(final['ra'])):
    finra.append(final['ra'][i] + (mas_deg(final['pmra'][i] * 1000000)))
    findec.append(final['dec'][i] + (mas_deg(final['pmdec'][i] * 1000000)))
    findist.append(final['dist'][i] + final['rad_v'][i]* 1000000) # pc + pc 
final['finra'] = finra
final['findec'] = findec
final['findist'] = findist

# arc/yr, magnitude of <ra + dec> 
for i in range(len(final['pmra'])):
    pm_scalar.append(np.sqrt((final['pmra'][i]/1000)**2+(final['pmdec'][i]/1000)**2))
tang_v = [pm_scalar[i]*final['dist'][i]*4.74 for i in range(len(pm_scalar))] # km/s 
final['pm_scalar'] = pm_scalar
final['tang_v'] = tang_v
final['true_v'] = [np.sqrt((final['tang_v'][i])**2 + (final['radial_velocity'][i])**2) \
                   for i in range(len(final['tang_v']))]
final.head()
# Out:
#       source_id         ra  ra_error        dec  dec_error        pmra  \
# 0  3.212750e+18  74.609528  0.067774  -3.732688   0.058693   82.984264
# 1  3.314484e+18  66.996162  0.109210  18.500106   0.068009  104.045114
# 2  5.254824e+16  64.139976  0.040546  21.907302   0.022551  104.830750
# 3  3.313948e+18  66.093255  0.066379  17.078840   0.028903   99.753418
# 4  3.406943e+18  73.098408  0.039849  18.996756   0.024108   79.128360
#
#    pmra_error      pmdec  pmdec_error  radial_velocity    ...      \
# 0    0.145191  44.645771     0.111107        46.286953    ...
# 1    0.254961 -39.015701     0.196597        34.509997    ...
# 2    0.093303 -38.403547     0.070981        38.122167    ...
# 3    0.167299 -26.880896     0.092871        38.538139    ...
# 4    0.082338 -35.218230     0.045609        41.425628    ...
#
#    phot_bp_mean_mag  phot_rp_mean_mag       dist     rad_v      finra  \
# 0          7.101802          6.430762  51.163535  0.000047  97.660713
# ...

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.set_xlim3d(30, 90)
ax.set_ylim3d(40, 55)
ax.set_zlim3d(-5, 35)
ax.set_xlabel('ra')
ax.set_ylabel('distance (pc)')
ax.set_zlabel('dec')
ax.set_title('3d Space Motion')

start = [final['ra'],final['dist'],final['dec']]
end = [final['finra'],final['findist'],final['findec']]
# ra = y, dist = x, dec = z

ax.quiver(start[0], start[1], start[2], end[0], end[1], end[2], length = 1, normalize = True)

plt.show()
print('Center of Mass: ({} ra, {} dec)'.format(round(np.mean(final['ra']),2),round(np.mean(final['dec']),2)))
print('Perryman et al., 1998, (66.75 ra, 15.6 dec)')
# Out:
# Center of Mass: (67.88 ra, 16.11 dec)
# Perryman et al., 1998, (66.75 ra, 15.6 dec)

# %%
dr2_worv = 'SELECT TOP 10000 gaia.source_id, gaia.ra, gaia.ra_error, gaia.dec, gaia.dec_error, \
gaia.pmra, gaia.pmra_error, gaia.pmdec, gaia.pmdec_error, gaia.parallax, gaia.parallax_error, \
gaia.phot_g_mean_mag, gaia.phot_bp_mean_mag, gaia.phot_rp_mean_mag FROM gaiadr2.gaia_source as gaia \
WHERE gaia.ra >= 35 and gaia.ra <= 95 and gaia.dec <= 40 and gaia.dec >= -5 and gaia.parallax > 19.5 \
and gaia.parallax < 23.5 and gaia.pmra is not null and gaia.pmdec is not null and \
gaia.phot_bp_mean_mag is not null and gaia.phot_rp_mean_mag is not null and \
gaia.phot_g_mean_mag is not null and gaia.radial_velocity is null'

# gaia.dr2 without radial velocity
hyades2 = pd.read_csv('/Users/landonbuechner/Documents/Git Hub Repositories/Hyades-Open-Cluster/dr2_worv.csv') 

def rad(x):
    return x*math.pi/180
def mult_uncertainty(x,dx,y,dy,z,dz):
    return np.sqrt((dx/x)**2+(dy/y)**2+(dz/z)**2)
def power_uncertainty(x,dx,n):
    return np.absolute(n)*(dx/np.absolute(x))

# hyades1 + hyades2
total_dr2 = pd.read_csv('/Users/landonbuechner/Documents/Git Hub Repositories/Hyades-Open-Cluster/dr2total.csv') 
# gaia.dr1
dr1 = pd.read_csv('/Users/landonbuechner/Documents/Git Hub Repositories/Hyades-Open-Cluster/tgas_errors.csv')
# hipparcos
hip = pd.read_csv('/Users/landonbuechner/Documents/Git Hub Repositories/Hyades-Open-Cluster/astrostat_hip.csv')

final.head()
# Out:
#       source_id         ra  ra_error        dec  dec_error        pmra  \
# 0  3.212750e+18  74.609528  0.067774  -3.732688   0.058693   82.984264
# 1  3.314484e+18  66.996162  0.109210  18.500106   0.068009  104.045114
# 2  5.254824e+16  64.139976  0.040546  21.907302   0.022551  104.830750
# 3  3.313948e+18  66.093255  0.066379  17.078840   0.028903   99.753418
# 4  3.406943e+18  73.098408  0.039849  18.996756   0.024108   79.128360
#
#    pmra_error      pmdec  pmdec_error  radial_velocity    ...      \
# 0    0.145191  44.645771     0.111107        46.286953    ...
# 1    0.254961 -39.015701     0.196597        34.509997    ...
# 2    0.093303 -38.403547     0.070981        38.122167    ...
# 3    0.167299 -26.880896     0.092871        38.538139    ...
# 4    0.082338 -35.218230     0.045609        41.425628    ...
#
#    phot_bp_mean_mag  phot_rp_mean_mag       dist     rad_v      finra  \
# 0          7.101802          6.430762  51.163535  0.000047  97.660713
# ...

# %%
# angle and rv of data with spectroscopic rv
pm_scalar_error = []
for i in range(len(final['pmra'])):
    pm = np.sqrt((final['pmra'][i]/1000)**2+(final['pmdec'][i]/1000)**2)
    x = power_uncertainty(final['pmra'][i]/1000,final['pmra_error'][i]/1000,2)
    y = power_uncertainty(final['pmdec'][i]/1000,final['pmdec_error'][i]/1000,2)
    z = np.sqrt((x**2)+(y**2))
    uncert = power_uncertainty(pm,z,.5)
    pm_scalar_error.append(uncert)
final['pm_scalar_error'] = pm_scalar_error

lambd = []
lambd_error = []
for i in range(len(final)):
    x = 180*math.atan(4.74*final['pm_scalar'][i]/final['radial_velocity'][i]*final['dist'][i])/math.pi
    lambd.append(x)
    y = mult_uncertainty(4.74*final['pm_scalar'][i],4.74*final['pm_scalar_error'][i],\
                              final['radial_velocity'][i],final['radial_velocity_error'][i],\
                              final['parallax'][i],final['parallax_error'][i])
    # Propogate lambda errors properly to calculate the uncertainty in the mean of lambda, then those two variabels are set and we gucci
    uncert = (180*(1/(1+x))/math.pi)*y
    lambd_error.append(uncert)
    
plt.hist(lambd,bins = 50, color = (39/255, 86/255, 173/255))
plt.ylabel('Frequency')
plt.xlabel('Degrees')
plt.title('Distribution of Lambda')
plt.show()

plt.hist(lambd_error,bins = 100, color = (39/255, 86/255, 173/255))
plt.ylabel('Frequency')
plt.xlabel('Degrees')
plt.title('Lambda Errors')
plt.show()

rvs = []
for i in range(len(final)):
    rvs.append((4.74*final['pm_scalar'][i]*final['dist'][i])/(np.tan(np.radians(lambd[i]))))
    
plt.hist(rvs,bins = 50, color = (39/255, 86/255, 173/255))
plt.ylabel('Frequency')
plt.xlabel('RV')
plt.title('Calculated - Moving Cluster Radial Velocities')
plt.show()
print('Mean Spectroscopic Radial Velocities: {} km/s^-1'.format(round(np.mean(final['radial_velocity']),2)))
print('- Checking: Radial Velocities from moving cluster method: {} km/s^-1'.format(round(np.mean(rvs),2)))
# Out:
# Mean Spectroscopic Radial Velocities: 36.12 km/s^-1
# - Checking: Radial Velocities from moving cluster method: 36.12 km/s^-1

# %%
# inspecting outliers - angle 
print('- Stars Filtered Due to Extreme Lambda -')
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.set_xlim3d(30, 90)
ax.set_ylim3d(40, 55)
ax.set_zlim3d(-5, 35)
ax.set_xlabel('ra')
ax.set_ylabel('distance (pc)')
ax.set_zlabel('dec')
ax.set_title('3d Space Motion')
start = [final['ra'],final['dist'],final['dec']]
end = [final['finra'],final['findist'],final['findec']]
ax.quiver(start[0], start[1], start[2], end[0], end[1], end[2], length = 2, normalize = True)

# angles
extreme_angles = [i for i in range(len(lambd)) if lambd[i] < 0 or lambd[i] > 55]
extr1 = []
for i in range(len(extreme_angles)):
    x = (final.loc[i])
    start = [x['ra'],x['dist'],x['dec']]
    end = [x['finra'],x['findist'],x['findec']]
    extr1.append(x)
    ax.quiver(start[0], start[1], start[2], end[0], end[1], end[2], length = 5, normalize = True, color = 'r')
    
extr1 = pd.DataFrame(extr1)
plt.show()

# plotting results 
plt.figure(figsize=(8,8))
plt.xlim([120,35])
plt.ylim([-7,37])
plt.ylabel('dec (deg)')
plt.xlabel('ra (deg)')
plt.title('Observed members of Hyades - {} stars'.format(len(extreme_angles)))

ra0, dec0 = final['ra'], final['dec'] 
pmra, pmdec = mas_deg(final['pmra']), mas_deg(final['pmdec'])
for i in range(len(final)):
    ra = []
    dec = []
    for x in range(1,5000,10):
        ra.append(ra0[i]+(pmra[i]*x*1000))
        dec.append(dec0[i]+(pmdec[i]*x*1000))
    if i in extreme_angles:
        plt.scatter(ra, dec, s = .5, c = 'r')
    else:
        plt.scatter(ra, dec, s = .2, c = 'k')
plt.show()
# Out:
# - Stars Filtered Due to Extreme Lambda -

# %%
# inspecting outliers - lambda error 
print('- Stars Filtered Due to Extreme Lambda Error -')
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.set_xlim3d(30, 90)
ax.set_ylim3d(40, 55)
ax.set_zlim3d(-5, 35)
ax.set_xlabel('ra')
ax.set_ylabel('distance (pc)')
ax.set_zlabel('dec')
ax.set_title('3d Space Motion')
start = [final['ra'],final['dist'],final['dec']]
end = [final['finra'],final['findist'],final['findec']]
ax.quiver(start[0], start[1], start[2], end[0], end[1], end[2], length = 2, normalize = True)

# angles
extreme_lambda = [i for i in range(len(lambd_error)) if lambd_error[i] > 4 or lambd_error[i] < -2]
extr2 = []
for i in range(len(extreme_lambda)):
    x = (final.loc[i])
    start = [x['ra'],x['dist'],x['dec']]
    end = [x['finra'],x['findist'],x['findec']]
    extr2.append(x)
    ax.quiver(start[0], start[1], start[2], end[0], end[1], end[2], length = 5, normalize = True, color = 'r')

plt.figure(figsize=(8,8))
plt.xlim([120,35])
plt.ylim([-7,37])
plt.ylabel('dec (deg)')
plt.xlabel('ra (deg)')
plt.title('Observed members of Hyades - {} stars'.format(len(extreme_lambda)))

ra0, dec0 = final['ra'], final['dec'] 
pmra, pmdec = mas_deg(final['pmra']), mas_deg(final['pmdec'])
for i in range(len(final)):
    ra = []
    dec = []
    for x in range(1,5000,10):
        ra.append(ra0[i]+(pmra[i]*x*1000))
        dec.append(dec0[i]+(pmdec[i]*x*1000))
    if i in extreme_lambda:
        plt.scatter(ra, dec, s = .5, c = 'r')
    else:
        plt.scatter(ra, dec, s = .2, c = 'k')
plt.show()
extr2 = pd.DataFrame(extr2)
plt.show()
# Out:
# - Stars Filtered Due to Extreme Lambda Error -

# %%
# inspecting outliers - radial velocity
print('Stars Filtered Due to Extreme Radial Velocities')
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.set_xlim3d(30, 90)
ax.set_ylim3d(40, 55)
ax.set_zlim3d(-5, 35)
ax.set_xlabel('ra')
ax.set_ylabel('distance (pc)')
ax.set_zlabel('dec')
ax.set_title('3d Space Motion')
start = [final['ra'],final['dist'],final['dec']]
end = [final['finra'],final['findist'],final['findec']]
ax.quiver(start[0], start[1], start[2], end[0], end[1], end[2], length = 2, normalize = True)

extreme_rvs = [i for i in range(len(rvs)) if rvs[i] < 20]
extr2 = []
for i in range(len(extreme_rvs)):
    x = (final.loc[i])
    start = [x['ra'],x['dist'],x['dec']]
    end = [x['finra'],x['findist'],x['findec']]
    extr2.append(x)
    ax.quiver(start[0], start[1], start[2], end[0], end[1], end[2], length = 5, normalize = True, color = 'r')

plt.figure(figsize=(8,8))
plt.xlim([120,35])
plt.ylim([-7,37])
plt.ylabel('dec (deg)')
plt.xlabel('ra (deg)')
plt.title('Observed members of Hyades - {} stars'.format(len(extreme_rvs)))

ra0, dec0 = final['ra'], final['dec'] 
pmra, pmdec = mas_deg(final['pmra']), mas_deg(final['pmdec'])
for i in range(len(final)):
    ra = []
    dec = []
    for x in range(1,5000,10):
        ra.append(ra0[i]+(pmra[i]*x*1000))
        dec.append(dec0[i]+(pmdec[i]*x*1000))
    if i in extreme_rvs:
        plt.scatter(ra, dec, s = .5, c = 'r')
    else:
        plt.scatter(ra, dec, s = .2, c = 'k')
plt.show()
extr2 = pd.DataFrame(extr2)
plt.show()
# Out:
# Stars Filtered Due to Extreme Radial Velocities

# %%
print('# of members before filtering possible non-members (stored in extr1 and extr2): {}'.format(len(final)))
extremes = extreme_rvs + extreme_angles + extreme_lambda
testt = []
for i in range(len(final)):
    if i in extremes:
        pass
    else:
        testt.append(list(final.loc[i]))

final = pd.DataFrame(testt, columns = list(final))
print('# of members after: {}'.format(len(final)))
print()

plt.figure(figsize=(8,8))
plt.xlim([120,35])
plt.ylim([-7,37])
plt.ylabel('dec (deg)')
plt.xlabel('ra (deg)')
plt.title('Observed members of Hyades - {} stars'.format(len(final)))

ra0, dec0 = final['ra'], final['dec'] 
pmra, pmdec = mas_deg(final['pmra']), mas_deg(final['pmdec'])
for i in range(len(final)):
    ra = []
    dec = []
    for x in range(1,5000,10):
        ra.append(ra0[i]+(pmra[i]*x*1000))
        dec.append(dec0[i]+(pmdec[i]*x*1000))
    plt.scatter(ra, dec, s = .2, c = 'k')
plt.show()

# Have to adjust data for dropped stars 
lambd = []
for i in range(len(final)):
    lambd.append(180*math.atan(4.74*final['pm_scalar'][i]/final['radial_velocity'][i]*final['dist'][i])/math.pi)
lambd_av = np.mean(lambd)
lambd_Er = np.round(np.sqrt(sum([i**2 for i in lambd_error]))\
                                        /(len(lambd_error)**2),4)

plt.hist(lambd,bins = 25, color = (39/255, 86/255, 173/255))
plt.ylabel('Frequency')
plt.xlabel('Degrees')
plt.xlim([0,65])
plt.title('Calculated From Data Without RV')
plt.show()

rvs = []
for i in range(len(final)):
    rvs.append((4.74*final['pm_scalar'][i]*final['dist'][i])/(np.tan(np.radians(lambd[i]))))
    
plt.hist(rvs,bins = 15, color = (39/255, 86/255, 173/255))
plt.ylabel('Frequency')
plt.xlabel('RV')
plt.xlim([0,80])
plt.title('Moving Cluster Radial Velocities')
plt.show()
print("- POST FILTERING - ")
print('Mean Spectroscopic Radial Velocities: {} km/s^-1'.format(round(np.mean(final['radial_velocity']),2)))
print('Radial Velocities from moving cluster method: {} km/s^-1'.format(round(np.mean(rvs),2)))
print('Mean Lambda: {} +- {} deg'.format(round(lambd_av,3),round(lambd_Er,3)))
# Out:
# # of members before filtering possible non-members (stored in extr1 and extr2): 130
# # of members after: 119
# - POST FILTERING -
# Mean Spectroscopic Radial Velocities: 39.34 km/s^-1
# Radial Velocities from moving cluster method: 39.34 km/s^-1
# Mean Lambda: 31.848 +- 0.001 deg

# %%
hyades2['dist'] = [1/(i/1000) for i in hyades2['parallax']]
hyades2['dist_error'] = [1/(i/1000) for i in hyades2['parallax_error']]

pm_scalar = []
pm_scalar_error = []
for i in range(len(hyades2['pmra'])):
    pm = np.sqrt((hyades2['pmra'][i]/1000)**2+(hyades2['pmdec'][i]/1000)**2)
    x = power_uncertainty(hyades2['pmra'][i]/1000,hyades2['pmra_error'][i]/1000,2)
    y = power_uncertainty(hyades2['pmdec'][i]/1000,hyades2['pmdec_error'][i]/1000,2)
    z = np.sqrt((x**2)+(y**2))
    uncert = power_uncertainty(pm,z,.5)
    pm_scalar.append(pm)
    pm_scalar_error.append(uncert)
    
hyades2['pm_scalar'] = pm_scalar
hyades2['pm_scalar_error'] = pm_scalar_error
tang_v = [pm_scalar[i]*hyades2['dist'][i]*4.74 for i in range(len(pm_scalar))] # km/s

# %%
rvs = []
rvs_error = []
for i in range(len(hyades2)):
    rv = (4.74*hyades2['pm_scalar'][i]/(np.tan(np.radians(lambd_av))*(hyades2['parallax'][i]/1000)))
    uncert = mult_uncertainty(4.74*hyades2['pm_scalar'][i],4.74*hyades2['pm_scalar_error'][i],\
                              hyades2['parallax'][i],hyades2['parallax_error'][i],\
                              np.tan(np.radians(lambd_av)),np.tan(np.radians(lambd_Er)))
    rvs.append(rv)
    rvs_error.append(uncert)
hyades2['rad_v'] = rvs
hyades2['rad_v_error'] = rvs_error

# plotting and filtering
ra0, dec0 = hyades2['ra'], hyades2['dec'] 
pmra, pmdec = mas_deg(final['pmra']), mas_deg(final['pmdec'])
pmraT, pmdecT= mas_deg(hyades2['pmra']), mas_deg(hyades2['pmdec'])

members1 = []
delta = pmdecT
mu = np.mean(pmdec)
std = np.std(pmdec)
score1 = [z_score(i,mu,std) for i in delta]
delta = pmraT
mu = np.mean(pmra)
std = np.std(pmra)
score2 = [z_score(i,mu,std) for i in delta]

for i in range(0,len(delta)):
    if score1[i] >=   -1.65 and score1[i] <=  1.65 \
        and score2[i] >=  -1.65 and score2[i] <=  1.65:
       # and score3[i] >=  -1.65 and score3[i] <=  1.65:
            members1.append(list(hyades2.loc[i]))

members1 = pd.DataFrame(members1, columns = list(hyades2))

ra0, dec0 = members1['ra'], members1['dec'] 
pmra, pmdec = mas_deg(members1['pmra']), mas_deg(members1['pmdec'])
final1 = []
raa = []
decc = []
for i in range(len(members1)):
    ra = []
    dec = []
    for x in range(1,5000,10):
        ra.append(ra0[i]+(pmra[i]*x*1000))
        dec.append(dec0[i]+(pmdec[i]*x*1000))
    raa.append(ra)
    decc.append(dec)

# D = [99,96] x [9,6]
for i in range(len(raa)):
    for x in range(len(raa[i])):
        if raa[i][x] <= 99 and raa[i][x] >= 96 and \
        decc[i][x] <= 9 and decc[i][x] >= 7:
            final1.append(list(members1.loc[i]))
            break

plt.figure(figsize=(8,8))
plt.xlim([120,35])
plt.ylim([-7,37])
plt.ylabel('dec (deg)')
plt.xlabel('ra (deg)')
plt.title('Observed members of Hyades - {} stars'.format(len(final1)))
final1 = pd.DataFrame(final1, columns = list(hyades2))
ra0, dec0 = final1['ra'], final1['dec'] 
pmra, pmdec = mas_deg(final1['pmra']), mas_deg(final1['pmdec'])
for i in range(len(final1)):
    ra = []
    dec = []
    for x in range(1,5000,10):
        ra.append(ra0[i]+(pmra[i]*x*1000))
        dec.append(dec0[i]+(pmdec[i]*x*1000))
    plt.scatter(ra, dec, s = .2, c = 'k'  )
plt.show()

# %%
plt.hist(final1['pm_scalar'],bins = 15, color = (39/255, 86/255, 173/255))
plt.ylabel('Frequency')
plt.xlabel('arc/yr')
plt.title("pm_scalar")
plt.show()

plt.hist(final1['pm_scalar_error'],bins = 15, color = (39/255, 86/255, 173/255))
plt.ylabel('Frequency')
plt.xlabel('arc/yr')
plt.title("pm_scalar_error (1)")
plt.show()

plt.hist(final1['pm_scalar_error'],bins = 50, color = (39/255, 86/255, 173/255))
plt.ylabel('Frequency')
plt.xlabel('arc/yr')
plt.xlim([0,1.5])
plt.title("pm_scalar_error zoomed (2)")
plt.show()

plt.hist(final1['rad_v'],bins = 15, color = (39/255, 86/255, 173/255))
plt.ylabel('Frequency')
plt.xlabel('km*s^-1')
plt.xlim([28,51])
plt.title("rad_v")
plt.show()

plt.hist(final1['rad_v_error'],bins = 15, color = (39/255, 86/255, 173/255))
plt.ylabel('Frequency')
plt.xlabel('km*s^-1')
plt.title("Estimtaed RV's Error (1)")
plt.show()

plt.hist(final1['rad_v_error'],bins = 50, color = (39/255, 86/255, 173/255))
plt.ylabel('Frequency')
plt.xlabel('km*s^-1')
plt.xlim([0,10])
plt.title("Estimtaed RV's Error (2) - Zoomed")
plt.show()

print('Average Radial Velocity: {} km*s^-1 +- {}'.format(round(np.mean(final1['rad_v']),4),\
                                        np.round(sum([i**2 for i in final1['rad_v_error']])\
                                        /(len(final1['rad_v_error'])**2),4)))
print('CERN (Source 3): ({},{}) km*s^-1'.format(39.42-0.36,39.42+0.36)) # not a confidence interval
# Out:
# Average Radial Velocity: 37.4864 km*s^-1 +- 0.7486
# CERN (Source 3): (39.06,39.78) km*s^-1

# %%
# more outlier inspection 
finra = []
findec = []
findist = []
for i in range(len(final1['ra'])):
    finra.append(final1['ra'][i] + (mas_deg(final1['pmra'][i] * 1000000)))
    findec.append(final1['dec'][i] + (mas_deg(final1['pmdec'][i] * 1000000)))
    findist.append(final1['dist'][i] + final1['rad_v'][i]* 1000000) # pc + pc 
final1['finra'] = finra
final1['findec'] = findec
final1['findist'] = findist

# inspecting outliers - radial velocity
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.set_xlim3d(30, 90)
ax.set_ylim3d(40, 55)
ax.set_zlim3d(-5, 35)
ax.set_xlabel('ra')
ax.set_ylabel('distance (pc)')
ax.set_zlabel('dec')
ax.set_title('3d Space Motion')
start = [final1['ra'],final1['dist'],final1['dec']]
end = [final1['finra'],final1['findist'],final1['findec']]
ax.quiver(start[0], start[1], start[2], end[0], end[1], end[2], length = 2, normalize = True)

# angles
extreme_pm_error = [i for i in range(len(final1['pm_scalar_error'])) if final1['pm_scalar_error'][i] > 1.5]
extr2 = []
for i in range(len(extreme_pm_error)):
    x = (final1.loc[i])
    start = [x['ra'],x['dist'],x['dec']]
    end = [x['finra'],x['findist'],x['findec']]
    extr2.append(x)
    ax.quiver(start[0], start[1], start[2], end[0], end[1], end[2], length = 7, normalize = True, color = 'r')

plt.figure(figsize=(8,8))
plt.xlim([120,35])
plt.ylim([-7,37])
plt.ylabel('dec (deg)')
plt.xlabel('ra (deg)')
plt.title('Extreme error lambda - {} stars'.format(len(extreme_pm_error)))

ra0, dec0 = final1['ra'], final1['dec'] 
pmra, pmdec = mas_deg(final1['pmra']), mas_deg(final1['pmdec'])
for i in range(len(final1)):
    ra = []
    dec = []
    for x in range(1,5000,10):
        ra.append(ra0[i]+(pmra[i]*x*1000))
        dec.append(dec0[i]+(pmdec[i]*x*1000))
    if i in extreme_pm_error:
        plt.scatter(ra, dec, s = .5, c = 'r')
    else:
        plt.scatter(ra, dec, s = .2, c = 'k')
plt.show()
extr2 = pd.DataFrame(extr2)
plt.show()

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.set_xlim3d(30, 90)
ax.set_ylim3d(40, 55)
ax.set_zlim3d(-5, 35)
ax.set_xlabel('ra')
ax.set_ylabel('distance (pc)')
ax.set_zlabel('dec')
ax.set_title('3d Space Motion')
start = [final1['ra'],final1['dist'],final1['dec']]
end = [final1['finra'],final1['findist'],final1['findec']]
ax.quiver(start[0], start[1], start[2], end[0], end[1], end[2], length = 2, normalize = True)

# angles
extreme_rad_v_error = [i for i in range(len(final1['rad_v_error'])) if final1['rad_v_error'][i] > 15]
extr2 = []
for i in range(len(extreme_rad_v_error)):
    x = (final1.loc[i])
    start = [x['ra'],x['dist'],x['dec']]
    end = [x['finra'],x['findist'],x['findec']]
    extr2.append(x)
    ax.quiver(start[0], start[1], start[2], end[0], end[1], end[2], length = 7, normalize = True, color = 'r')

plt.figure(figsize=(8,8))
plt.xlim([120,35])
plt.ylim([-7,37])
plt.ylabel('dec (deg)')
plt.xlabel('ra (deg)')
plt.title('Extreme error rv - {} stars'.format(len(extreme_rad_v_error)))

ra0, dec0 = final1['ra'], final1['dec'] 
pmra, pmdec = mas_deg(final1['pmra']), mas_deg(final1['pmdec'])
for i in range(len(final1)):
    ra = []
    dec = []
    for x in range(1,5000,10):
        ra.append(ra0[i]+(pmra[i]*x*1000))
        dec.append(dec0[i]+(pmdec[i]*x*1000))
    if i in extreme_rad_v_error:
        plt.scatter(ra, dec, s = .5, c = 'r')
    else:
        plt.scatter(ra, dec, s = .2, c = 'k')
plt.show()
extr2 = pd.DataFrame(extr2)
plt.show()

# %%
print('# of members before filtering extreme error observations (stored in extr1 and extr2): {}'.format(len(final1)))
extremes = extreme_pm_error + extreme_rad_v_error
testt = []
for i in range(len(final1)):
    if i in extremes:
        pass
    else:
        testt.append(list(final1.loc[i]))

final1 = pd.DataFrame(testt, columns = list(final1))
print('# of members after: {}'.format(len(final1)))
print()

plt.figure(figsize=(8,8))
plt.xlim([120,35])
plt.ylim([-7,37])
plt.ylabel('dec (deg)')
plt.xlabel('ra (deg)')
plt.title('Observed members of Hyades - {} stars'.format(len(final1)))

ra0, dec0 = final1['ra'], final1['dec'] 
pmra, pmdec = mas_deg(final1['pmra']), mas_deg(final1['pmdec'])
for i in range(len(final1)):
    ra = []
    dec = []
    for x in range(1,5000,10):
        ra.append(ra0[i]+(pmra[i]*x*1000))
        dec.append(dec0[i]+(pmdec[i]*x*1000))
    plt.scatter(ra, dec, s = .2, c = 'k')
plt.show()
# Out:
# # of members before filtering extreme error observations (stored in extr1 and extr2): 175
# # of members after: 172

# %%
M_g = [abs_mag(final1['phot_g_mean_mag'][i],final1['parallax'][i]) for i in range(len(final1['ra']))]
M_rp = [abs_mag(final1['phot_rp_mean_mag'][i],final1['parallax'][i]) for i in range(len(final1['ra']))]
M_b = [abs_mag(final1['phot_bp_mean_mag'][i],final1['parallax'][i]) for i in range(len(final1['ra']))]
color_index1 = color(M_rp,M_b)
plt.figure(figsize=(7,7))
plt.title('Color-Magnitude - Hyades - {} Stars'.format(len(final)+len(final1)))
plt.xlabel('(Bp-Rp)')
plt.ylabel('Absolute Magnitude ')
plt.xlim([-1,5])
plt.ylim([19,1])
plt.scatter(color_indexF, M_gF,marker='o', s=25, alpha = .5,c = 'b')
plt.scatter(color_index1, M_g,marker='o', s=25, alpha = .5,c = 'r')
plt.style.use('seaborn')
plt.show()
final1.head()
# Out:
#       source_id         ra  ra_error        dec  dec_error       pmra  \
# 0  1.470225e+17  71.132172  0.060269  23.940876   0.037630  86.242118
# 1  3.306443e+18  69.291679  0.051895  12.105463   0.030483  88.815709
# 2  4.944851e+16  65.122873  0.532371  21.378551   0.279436  98.766760
# 3  3.314394e+18  66.590890  0.083479  18.000157   0.037766  98.236443
# 4  3.307198e+18  66.064528  0.079852  12.247237   0.050285  99.629378
#
#    pmra_error      pmdec  pmdec_error   parallax      ...       \
# 0    0.137844 -48.781909     0.061741  19.503057      ...
# 1    0.150399 -10.684800     0.066291  19.532960      ...
# 2    1.144194 -38.348703     0.830481  19.547070      ...
# 3    0.191570 -29.888829     0.109602  19.551517      ...
# 4    0.176872 -12.690243     0.110404  19.618748      ...
#
#    phot_rp_mean_mag       dist    dist_error  pm_scalar  pm_scalar_error  \
# 0         12.980967  51.274013  14345.669643   0.099083         0.020576
# ...

# %%
# Estimated distance to Hyades open cluster with 95% level of confidence (bootstrap resampling)
dist = list(1/(final['parallax']/1000)) + list(final1['dist'])
samp = len(dist) # sample size 
p_boot = []
for i in range(10000):
    index = [rand.randint(0,samp-1) for i in range(samp)]
    p_boot.append(np.mean([dist[i] for i in index]))
    
plt.hist(p_boot,bins = 100, color = (39/255, 86/255, 173/255))
plt.title('Boostrap Sampling Distribution - 2500')
plt.ylabel('Frequency')
plt.xlabel('Distance (pc)')
plt.show()

x = np.arange(round(min(p_boot),3),round(max(p_boot),3),.001)
cdf = []
for i in x:
    cdf.append(sum(x < i for x in p_boot)/len(p_boot))
plt.scatter(x, cdf, s=2, color=(39/255, 86/255, 173/255))
plt.xlabel('X')
plt.ylabel('cdf(X)')
plt.show()

lower = 0
upper = 0
for i in range(len(cdf)):
    if cdf[i] >= .049 and cdf[i] <= .051:
        lower = i
        break
for i in range(len(cdf)):
    if cdf[i] >= .949 and cdf[i] <= .951:
        upper = i
        break

# %%
final1['dist'] = [1/(i/1000) for i in final1['parallax']] # pc 
finra = []
findec = []
findist = []
pm_scalar = []

# final positions of additional stars 
for i in range(len(final1['ra'])):
    finra.append(final1['ra'][i] + (mas_deg(final1['pmra'][i] * 1000000)))
    findec.append(final1['dec'][i] + (mas_deg(final1['pmdec'][i] * 1000000)))
    findist.append(final1['dist'][i] + final1['rad_v'][i]* 1000000 * (1.022035e-6)) # pc + pc , kms -> pc/yr
for i in range(len(final1['pmra'])):
    pm_scalar.append(np.sqrt((final1['pmra'][i]/1000)**2+(final1['pmdec'][i]/1000)**2))
tang_v = [pm_scalar[i]*final1['dist'][i]*4.74 for i in range(len(pm_scalar))] # km/s 
final1['finra'] = finra
final1['findec'] = findec
final1['findist'] = findist
final1['pm_scalar'] = pm_scalar
final1['tang_v'] = tang_v
final1['true_v'] = [np.sqrt((final1['tang_v'][i])**2 + (final1['rad_v'][i])**2) \
                   for i in range(len(final1['tang_v']))]

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.set_xlim3d(30, 90)
ax.set_ylim3d(40, 55)
ax.set_zlim3d(-5, 35)
ax.set_xlabel('ra')
ax.set_ylabel('distance (pc)')
ax.set_zlabel('dec')
ax.set_title('3d Space Motion')

start = [final['ra'],final['dist'],final['dec']]
end = [final['finra'],final['findist'],final['findec']]
start1 = [final1['ra'],final1['dist'],final1['dec']]
end1 = [final1['finra'],final1['findist'],final1['findec']]

# ra = y, dist = x, dec = z
ax.quiver(start[0], start[1], start[2], end[0], end[1], end[2], length = 1, normalize = True)
ax.quiver(start1[0], start1[1], start1[2], end1[0], end1[1], end1[2], length = 1, normalize = True,color ='r')

# combining df's
plt.show()
print('Total Hyades Members: {}'.format(len(final)+len(final1)))
print('- Hyades Members DR1 TGAS (Source 2): {}'.format(251))
print()
print('Estimated distance to Hyades open cluster ({} pc, {} pc), 90% confidence'.format(round(x[lower],2),round(x[upper],2)))
print('Perryman et al.(1998), 46.07 parsecs to 46.61 parsecs.')
print()
print('Center of Mass: ({} ra, {} dec)'.format(round((np.mean(final['ra'])+np.mean(final1['ra']))/2,2),\
                                               round((np.mean(final['dec'])+np.mean(final1['dec']))/2,2),2))
print('- Perryman et al., 1998: (66.75 ra, 15.6 dec)')
print()

rv = final['radial_velocity']
rv1 = final1['rad_v']
rv_error_astro = np.round(np.sqrt(sum([i**2 for i in final1['rad_v_error']]))\
                                        /(len(final1['rad_v_error'])**2),4)
rv_error_spec = np.round(np.sqrt(sum([i**2 for i in final['radial_velocity_error']]))\
                                        /(len(final['radial_velocity_error'])**2),4)
rv_avg_tot = np.round((sum(rv)+sum(rv1))/(len(final)+len(final1)),4)
rv_avg_error_tot = np.round(np.sqrt(rv_error_astro**2+rv_error_spec**2),4)

print('Avg. Radial Velocity - Spectroscopic : {} +- {} km/s^-1'.format(round(np.mean(final['radial_velocity']),4),\
     rv_error_spec))
print('Avg. Radial Velocity - Calculated rv: {} +- {} km/s^-1'\
      .format(np.round(np.mean(rv1),4),rv_error_astro))
print('Avg. Radial Velocity of Hyades Cluster: {} +- {} km/s^-1'.format(np.round(rv_avg_tot,4),rv_avg_error_tot,4))
print('- Detweiler et al., 1984: {} +- {} km*s^-1'.format(39,0.02))
print('- CERN (Source 3): ({},{}) km*s^-1'.format(39.42-0.36,39.42+0.36)) # not a confidence interval 
pm_avg = (sum(final['pm_scalar'])+sum(final1['pm_scalar']))/(len(final)+len(final1))
pm_error = np.round(sum([i**2 for i in final1['pm_scalar_error']])\
              /(len(final1['pm_scalar_error'])**2),4)
print()
print('Avg. Proper Motion: {} arc/yr +- {}'.format(round(pm_avg,4),pm_error))
# Out:
# Total Hyades Members: 291
# - Hyades Members DR1 TGAS (Source 2): 251
#
# Estimated distance to Hyades open cluster (46.64 pc, 47.05 pc), 90% confidence
# Perryman et al.(1998), 46.07 parsecs to 46.61 parsecs.
#
# Center of Mass: (67.99 ra, 16.05 dec)
# - Perryman et al., 1998: (66.75 ra, 15.6 dec)
#
# Avg. Radial Velocity - Spectroscopic : 39.3397 +- 0.0006 km/s^-1
# Avg. Radial Velocity - Calculated rv: 37.533 +- 0.0007 km/s^-1
# Avg. Radial Velocity of Hyades Cluster: 38.2718 +- 0.0009 km/s^-1
# - Detweiler et al., 1984: 39 +- 0.02 km*s^-1
# - CERN (Source 3): (39.06,39.78) km*s^-1
#
# Avg. Proper Motion: 0.1072 arc/yr +- 0.0001
